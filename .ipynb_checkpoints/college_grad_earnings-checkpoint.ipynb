# %% [markdown]
# # College Graduate Earnings
# ---
# *by Ian McNabb*
#
# The purpose of this notebook is to practice using Python, specifically the pandas, matplotlib, and numpy libraries, for parsing through data and creating visualizations. This is also used as an opportunity to refamiliarize myself with Jupyter Notebooks, creating new directories using bash, etc.
#
# *data source credit:* [The Wall Street Journal](https://www.kaggle.com/wsj/college-salaries)

# %% [markdown]
# **Temporary workflow/notes below (no api)**
#
# *struggling with requesting api for data, will come back to that*
# - start with parsing datafile with csv library
#     - How much do engineering degrees start off making in their career? Make a bar chart comparing them
#         - cannot convert string to float? Trying to convert row[1] (median salary) to float
#             - SOLVED: just needed a nights rest to realize it was the '$' and the ','
#         - created module 'format_salary' that returns an integer from read salary strings
#         - Having problems rendering pygal graph within jupyter notebook
#             - pygal seems to be out of date and not very compatible with ipython. Switched to matplotlib to make it easy
#     - What is the average median starting salary for every school type (engineering, party, liberal arts, state)?
#         - I realize this process would be quicker and easier in excel, but the point is to practice and learn python even if it's inefficient and using brute force at first
#         - figuring out how to create a dictionary containing a list of values for each key, then traversing through it
#         - using arrays from the numpy library may be a more efficient way to store and manipulate data in this situation
#         - what does *zip function even do? Seems like an easy solution plotting dictionaries
#             - Breaking down the code... items() method returns the dictionary as a list of tuples. "A view object that displays a list of a given dictionary's (key, value) tuple pair."
#             - zip() function takes iterables (lists, tuples, dict), aggregates them in a tuple, and returns it.
#             - might have something to do with positional arguments (*args). I understand that in the context of a creating a function but I still don't get what exactly it's doing here
# - spent a substantial amount of time learning about pandas (dataframes, series, sorting, filtering, grouping, etc.), now it's finally time to apply that knowledge.
#     - Why is the data type object and not string for each column??

# %%
import csv 
import matplotlib.pyplot as plt
from statistics import mean

# takes string in $xx,xxx.xx format and converts to integer
from format_salary import format_salary

# %% [markdown]
# **1. What is the median starting salary for all engineering majors?**

# %%
filepath = "college-salaries/degrees-that-pay-back.csv"

with open(filepath, 'r') as f_obj:
    reader = csv.reader(f_obj)
    header_row = next(reader)
    
    salaries = []
    engineers = []
    for row in reader:
        name = row[0]
        salary = row[1]
        if 'Engineering' in name: 
            engineers.append(name)
            salaries.append(format_salary(salary))

# %%
# create and format bar graph
plt.figure(figsize=(6.0,8.0))
plt.bar(engineers, salaries, width=0.5, bottom=0, log=True, color='b', alpha=0.5)
plt.xticks(rotation=20, horizontalalignment='right', fontsize='medium')
plt.xlabel('Majors', fontsize='xx-large', fontweight='heavy')
plt.ylabel('Starting Salary', fontsize='xx-large', fontweight='heavy')
plt.title("Engineering Majors Median Starting Salary", fontsize='xx-large', fontweight='heavy')
plt.show()

# %% [markdown]
# **2. What is the average median starting salary for every school type (engineering, party, liberal arts, state)?**

# %%
filepath = "college-salaries/salaries-by-college-type.csv"

with open(filepath, 'r') as f_obj:
    reader = csv.reader(f_obj)
    header_row = next(reader)
    
    # initialize lists to store read salaries for each school type
    eng_salary, party_salary, lib_salary, state_salary, ivy_salary = ([] for i in range(5))
    school_type = ['Engineering', 'Party', 'Liberal Arts', 'State', 'Ivy League']
    
    # build lists
    for row in reader:
        if row[1] == school_type[0]:
            eng_salary.append(format_salary(row[2]))
        elif row[1] == school_type[1]:
            party_salary.append(format_salary(row[2]))
        elif row[1] == school_type[2]:
            lib_salary.append(format_salary(row[2]))
        elif row[1] == school_type[3]:
            state_salary.append(format_salary(row[2]))
        else:
            ivy_salary.append(format_salary(row[2]))
    
    # create dictionary with school type as keys and average median salaries as values
    my_dict = {}
    my_dict['Engineering'] = mean(eng_salary)
    my_dict['Party'] = mean(party_salary)
    my_dict['Liberal Arts'] = mean(lib_salary)
    my_dict['State'] = mean(state_salary)
    my_dict['Ivy League'] = mean(ivy_salary)
    
    print("Engineering school average median salary: " + str(round(mean(eng_salary), 2)))
    print("Party school average median salary: " + str(round(mean(party_salary), 2)))
    print("Liberal Arts school average median salary: " + str(round(mean(lib_salary), 2)))
    print("State school average median salary: " + str(round(mean(state_salary), 2)))
    print("Ivy League school average median salary: " + str(round(mean(ivy_salary), 2)))

# %%
plt.figure(figsize=(6.0,8.0))
plt.bar(*zip(*my_dict.items()), width=0.5, color='g')
plt.xlabel('School Type', fontweight='heavy', fontsize='x-large')
plt.ylabel('Salary', fontweight='heavy', fontsize='xx-large')
plt.title('Average Median Starting Salary by School Type', fontsize='xx-large', fontweight='heavy')
plt.show()

# %% [markdown]
# ## Pandas/NumPy Libraries
# ---
#
# Now that I've learned how to use 'brute force' methods to explore data, it's time to learn how to use easier, more-efficient methods. In the realm of data science, pandas is unaminously the favorite library to use.

# %%
import numpy as np
import pandas as pd

from pandas_format_salary import format_pd

# %%
filepath = "college-salaries/salaries-by-region.csv"

df = pd.read_csv(filepath)

# pandas display options
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')
pd.set_option('display.max_rows', None) # display all rows in dataset
pd.set_option('display.max_columns', None) # display all columns in dataset

df.head()
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0            $70,400.00              $129,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $59,900.00              $112,000.00
# 4            $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $68,400.00                        $93,100.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $59,500.00                        $81,000.00
# 4                               NaN                       $54,800.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $184,000.00                       $257,000.00
# 1                      $161,000.00                                NaN
# 2                      $180,000.00                                NaN
# 3                      $149,000.00                       $201,000.00
# 4                      $157,000.00                                NaN

# %% [markdown]
# **Aggregate Statistics Grouped by Region:**

# %%
df_mod = df # create copy of df

# %%
df_mod.dtypes # why is data type object and not string?
# Out:
# School Name                          object
# Region                               object
# Starting Median Salary               object
# Mid-Career Median Salary             object
# Mid-Career 10th Percentile Salary    object
# Mid-Career 25th Percentile Salary    object
# Mid-Career 75th Percentile Salary    object
# Mid-Career 90th Percentile Salary    object
# dtype: object

# %%
columns = df.columns[2:] # create list of columns that have salary data
format_pd(df_mod, columns) # format salary columns into float type
# Out:
#                                            School Name        Region  \
# 0                                  Stanford University    California
# 1             California Institute of Technology (CIT)    California
# 2                                  Harvey Mudd College    California
# 3                   University of California, Berkeley    California
# 4                                   Occidental College    California
# 5                             Cal Poly San Luis Obispo    California
# 6       University of California at Los Angeles (UCLA)    California
# 7           University of California, San Diego (UCSD)    California
# 8                                       Pomona College    California
# 9              University of Southern California (USC)    California
# 10                     University of California, Davis    California
# 11              University of California, Irvine (UCI)    California
# 12                    San Jose State University (SJSU)    California
# 13      University of California, Santa Barbara (UCSB)    California
# 14            California State University (CSU), Chico    California
# 15       California State University, Fullerton (CSUF)    California
# 16               San Francisco State University (SFSU)    California
# 17                   San Diego State University (SDSU)    California
# 18     California State University, Long Beach (CSULB)    California
# 19       California State University, East Bay (CSUEB)    California
# 20         University of California, Santa Cruz (UCSC)    California
# 21      California State University, Sacramento (CSUS)    California
# 22           University of California, Riverside (UCR)    California
# 23      California State University, Northridge (CSUN)    California
# 24   California State University, Dominguez Hills (...    California
# 25       California State University (CSU), Stanislaus    California
# 26                           Humboldt State University    California
# 27                              Thomas Aquinas College    California
# 28                            Colorado School of Mines       Western
# 29              University of Colorado - Boulder (UCB)       Western
# 30   New Mexico Institute of Mining and Technology ...       Western
# 31                      Brigham Young University (BYU)       Western
# 32                               University of Arizona       Western
# 33                       University of Washington (UW)       Western
# 34                   Washington State University (WSU)       Western
# 35                     University of Colorado - Denver       Western
# 36                      Arizona State University (ASU)       Western
# 37                       Oregon State University (OSU)       Western
# 38                                  University of Utah       Western
# 39                    University of Nevada, Reno (UNR)       Western
# 40                                  Seattle University       Western
# 41                                 University of Idaho       Western
# 42                      University of New Mexico (UNM)       Western
# 43                           University of Puget Sound       Western
# 44                               Colorado College (CC)       Western
# 45                                        Reed College       Western
# 46                                     Whitman College       Western
# 47                         New Mexico State University       Western
# 48                     Colorado State University (CSU)       Western
# 49                          University of Wyoming (UW)       Western
# 50                               Utah State University       Western
# 51                                University of Oregon       Western
# 52                  Montana State University - Bozeman       Western
# 53                                  Gonzaga University       Western
# 54                                University of Hawaii       Western
# 55                       Western Washington University       Western
# 56                                    Regis University       Western
# 57                              Idaho State University       Western
# 58                     University of Alaska, Anchorage       Western
# 59                               Lewis & Clark College       Western
# 60                               University of Montana       Western
# 61              University of Nevada, Las Vegas (UNLV)       Western
# 62                     Portland State University (PSU)       Western
# 63                       Eastern Washington University       Western
# 64                                  Fort Lewis College       Western
# 65                        Boise State University (BSU)       Western
# 66                           Utah Valley State College       Western
# 67                             Evergreen State College       Western
# 68                            Southern Utah University       Western
# 69                 Montana State University - Billings       Western
# 70                            University of Notre Dame    Midwestern
# 71                               University Of Chicago    Midwestern
# 72                                    Carleton College    Midwestern
# 73              Illinois Institute of Technology (IIT)    Midwestern
# 74                     Case Western Reserve University    Midwestern
# 75   University of Illinois at Urbana-Champaign (UIUC)    Midwestern
# 76                             Northwestern University    Midwestern
# 77                University of Missouri - Rolla (UMR)    Midwestern
# 149                 George Washington University (GWU)      Southern
# 150                               Texas A&M University      Southern
# 151                                  Tulane University      Southern
# 152  Virginia Polytechnic Institute and State Unive...      Southern
# 153               University of Maryland, College Park      Southern
# 154                             University of Richmond      Southern
# 155                  University of Texas (UT) - Austin      Southern
# 156                                   Emory University      Southern
# 157               American University, Washington D.C.      Southern
# 158                                University of Tulsa      Southern
# 159                                  Baylor University      Southern
# 160                         University of Florida (UF)      Southern
# 161                   Louisiana State University (LSU)      Southern
# 162                            George Mason University      Southern
# 163                                 Clemson University      Southern
# 164                        University of Georgia (UGA)      Southern
# 165                                  Auburn University      Southern
# 166                             University of Delaware      Southern
# 167                             Randolph-Macon College      Southern
# 168             North Carolina State University (NCSU)      Southern
# 169                             University of Oklahoma      Southern
# 170                             University of Arkansas      Southern
# 171          University of Alabama at Huntsville (UAH)      Southern
# 172                                  Howard University      Southern
# 173  University of North Carolina at Chapel Hill (U...      Southern
# 174                  University of Alabama, Tuscaloosa      Southern
# 175             University of Texas at Arlington (UTA)      Southern
# 176                          Oklahoma State University      Southern
# 177                 Tennessee Technological University      Southern
# 178                         University of Houston (UH)      Southern
# 179                          University of Mississippi      Southern
# 180                                   Lamar University      Southern
# 181                 Mississippi State University (MSU)      Southern
# 182                        University of Kentucky (UK)      Southern
# 183                   Texas Christian University (TCU)      Southern
# 184                     West Virginia University (WVU)      Southern
# 185     University of Maryland Baltimore County (UMBC)      Southern
# 186          University of Louisiana (UL) at Lafayette      Southern
# 187             Florida International University (FIU)      Southern
# 188                            University of Tennessee      Southern
# 189          University of Arkansas - Monticello (UAM)      Southern
# 190   University of North Carolina at Charlotte (UNCC)      Southern
# 191                           Georgia State University      Southern
# 192                              LeTourneau University      Southern
# 193                     Florida State University (FSU)      Southern
# 194              University of Texas at El Paso (UTEP)      Southern
# 195                University of Central Florida (UCF)      Southern
# 196                       University of South Carolina      Southern
# 197                  Florida Atlantic University (FAU)      Southern
# 198                  University of South Florida (USF)      Southern
# 199          University of Texas at San Antonio (UTSA)      Southern
# 200          University of Alabama at Birmingham (UAB)      Southern
# 201                     University of Memphis (U of M)      Southern
# 202                       Appalachian State University      Southern
# 203             Virginia Commonwealth University (VCU)      Southern
# 204                     East Carolina University (ECU)      Southern
# 205                        Western Carolina University      Southern
# 206                            Jacksonville University      Southern
# 207  University of North Carolina at Wilmington (UNCW)      Southern
# 208                           Oklahoma City University      Southern
# 209                    Arkansas State University (ASU)      Southern
# 210                    Tarleton State University (TSU)      Southern
# 211                          Morehead State University      Southern
# 212                                Mississippi College      Southern
# 213                          Dallas Baptist University      Southern
# 214                       Austin Peay State University      Southern
# 215                               Saint Leo University      Southern
# 216                                   Tusculum College      Southern
# 217                    Virginia Wesleyan College (VWC)      Southern
# 218                     Lee University (Cleveland, TN)      Southern
# 219              Florida Metropolitan University (FMU)      Southern
# 220                                  Dartmouth College  Northeastern
# 221                               Princeton University  Northeastern
# 222        Massachusetts Institute of Technology (MIT)  Northeastern
# 223                                    Yale University  Northeastern
# 224                                 Harvard University  Northeastern
# 225                         University of Pennsylvania  Northeastern
# 226       Polytechnic University of New York, Brooklyn  Northeastern
# 227                                       Cooper Union  Northeastern
# 228              Worcester Polytechnic Institute (WPI)  Northeastern
# 229                   Carnegie Mellon University (CMU)  Northeastern
# 230             Rensselaer Polytechnic Institute (RPI)  Northeastern
# 231                                 Cornell University  Northeastern
# 232                                Bucknell University  Northeastern
# 233                                   Brown University  Northeastern
# 234                                 Colgate University  Northeastern
# 235                                Columbia University  Northeastern
# 236                                    Amherst College  Northeastern
# 237                                  Lafayette College  Northeastern
# 238                                    Bowdoin College  Northeastern
# 239                          College of the Holy Cross  Northeastern
# 240                    Stevens Institute of Technology  Northeastern
# 241                                  Lehigh University  Northeastern
# 242                                 Swarthmore College  Northeastern
# 243                                     Boston College  Northeastern
# 244                                   Williams College  Northeastern
# 245                               Villanova University  Northeastern
# 246                                 Fordham University  Northeastern
# 247      Wesleyan University (Middletown, Connecticut)  Northeastern
# 248                  Wentworth Institute of Technology  Northeastern
# 249                                      Bates College  Northeastern
# 250                              Binghamton University  Northeastern
# 251                                      Union College  Northeastern
# 252                          New York University (NYU)  Northeastern
# 253                                     Vassar College  Northeastern
# 254                                 Middlebury College  Northeastern
# 255                              Mount Holyoke College  Northeastern
# 256                                  Boston University  Northeastern
# 257                                  Drexel University  Northeastern
# 258                    St. John's University, New York  Northeastern
# 259                             Long Island University  Northeastern
# 260                             Stony Brook University  Northeastern
# 261                      Franklin and Marshall College  Northeastern
# 262                                 Hofstra University  Northeastern
# 263      State University of New York (SUNY) at Albany  Northeastern
# 264                                 Rutgers University  Northeastern
# 265                                    Pratt Institute  Northeastern
# 266                                    Pace University  Northeastern
# 267                              Seton Hall University  Northeastern
# 268                                   Rider University  Northeastern
# 269                  University of Connecticut (UConn)  Northeastern
# 270                                 Providence College  Northeastern
# 271      University of Massachusetts (UMass) - Amherst  Northeastern
# 272                                     Ithaca College  Northeastern
# 273       University of Massachusetts (UMass) - Lowell  Northeastern
# 274                            Northeastern University  Northeastern
# 275                                Syracuse University  Northeastern
# 276                                      Colby College  Northeastern
# 277                                 Gettysburg College  Northeastern
# 278                Pennsylvania State University (PSU)  Northeastern
# 279                   University of Rhode Island (URI)  Northeastern
# 280                                      Siena College  Northeastern
# 281                 La Salle University (Philadelphia)  Northeastern
# 282            Rochester Institute of Technology (RIT)  Northeastern
# 283                                Duquesne University  Northeastern
# 284  State University of New York (SUNY) at Farming...  Northeastern
# 285                                      Smith College  Northeastern
# 286                                   Hamilton College  Northeastern
# 287                                  Wellesley College  Northeastern
# 288                                 Widener University  Northeastern
# 289                            University of New Haven  Northeastern
# 290                                    Dowling College  Northeastern
# 291                        University of Vermont (UVM)  Northeastern
# 292     State University of New York (SUNY) at Buffalo  Northeastern
# 293     State University of New York (SUNY) at Geneseo  Northeastern
# 294                    Fashion Institute of Technology  Northeastern
# 295                            Philadelphia University  Northeastern
# 296                                    Ursinus College  Northeastern
# 297                                 Adelphi University  Northeastern
# 298                                    Juniata College  Northeastern
# 299                     Fairleigh Dickinson University  Northeastern
# 300                  University of New Hampshire (UNH)  Northeastern
# 260                           129000.0                           181000.0
# 261                           185000.0                                NaN
# 262                           135000.0                           189000.0
# 263                           135000.0                           209000.0
# 264                           128000.0                           176000.0
# 265                           123000.0                           155000.0
# 266                           129000.0                           187000.0
# 267                           133000.0                           195000.0
# 268                           127000.0                           150000.0
# 269                           120000.0                           162000.0
# 270                           138000.0                           194000.0
# 271                           122000.0                           168000.0
# 272                           128000.0                           174000.0
# 273                           113000.0                           158000.0
# 274                           117000.0                           159000.0
# 275                           119000.0                           178000.0
# 276                           129000.0                                NaN
# 277                           132000.0                                NaN
# 278                           117000.0                           160000.0
# 279                           112000.0                           157000.0
# 280                           129000.0                           189000.0
# 281                           106000.0                           151000.0
# 282                           112000.0                           159000.0
# 283                           107000.0                           131000.0
# 284                           110000.0                           162000.0
# 285                           129000.0                           184000.0
# 286                           123000.0                                NaN
# 287                           125000.0                                NaN
# 288                           106000.0                           138000.0
# 289                           113000.0                           157000.0
# 290                           117000.0                           142000.0
# 291                           122000.0                           194000.0
# 292                           110000.0                           147000.0
# 293                           117000.0                           173000.0
# 294                           106000.0                           138000.0
# 295                           108000.0                           141000.0
# 296                           100000.0                           160000.0
# 297                           114000.0                           160000.0
# 298                           110000.0                                NaN
# 299                           112000.0                           171000.0
# 300                           114000.0                           147000.0
# 301                           109000.0                           151000.0
# 302                           115000.0                           169000.0
# 303                           107000.0                           132000.0
# 304                            97700.0                           155000.0
# 305                           117000.0                           155000.0
# 306                           105000.0                           136000.0
# 307                           105000.0                           150000.0
# 308                           147000.0                                NaN
# 309                            94900.0                                NaN
# 310                           104000.0                           150000.0
# 311                            95100.0                           145000.0
# 312                            99600.0                           151000.0
# 313                           102000.0                           138000.0
# 314                            99300.0                           141000.0
# 315                           100000.0                           179000.0
# 316                            92000.0                           128000.0
# 317                            93300.0                           181000.0
# 318                            85700.0                           117000.0
# 319                            99000.0                           134000.0

# %%
# # format salary columns
# for col in df_mod.columns[2:]:
#     df_mod[col] = df_mod[col].astype(str) # cast as string
    
#     # remove non-numeric characters
#     df_mod[col] = df_mod[col].str.replace(',', '')
#     df_mod[col] = df_mod[col].str.replace('$', '')

#     df_mod[col] = df_mod[col].astype(float).round(decimals=0) # cast back to float

# %%
df_mod.dtypes
# Out:
# School Name                           object
# Region                                object
# Starting Median Salary               float64
# Mid-Career Median Salary             float64
# Mid-Career 10th Percentile Salary    float64
# Mid-Career 25th Percentile Salary    float64
# Mid-Career 75th Percentile Salary    float64
# Mid-Career 90th Percentile Salary    float64
# dtype: object

# %%
df_mod.groupby('Region').mean().round()
# Out:
#               Starting Median Salary  Mid-Career Median Salary  \
# Region
# California                   51032.0                   93132.0
# Midwestern                   44225.0                   78180.0
# Northeastern                 48496.0                   91352.0
# Southern                     44522.0                   79505.0
# Western                      44414.0                   78200.0
#
#               Mid-Career 10th Percentile Salary  \
# Region
# California                              47777.0
# Midwestern                              43077.0
# Northeastern                            49101.0
# Southern                                43075.0
# Western                                 42985.0
#
#               Mid-Career 25th Percentile Salary  \
# Region
# California                              67154.0
# Midwestern                              57027.0
# Northeastern                            65479.0
# Southern                                57506.0
# Western                                 56581.0
#
#               Mid-Career 75th Percentile Salary  \
# Region
# California                             127350.0
# Midwestern                             107594.0
# Northeastern                           129576.0
# Southern                               109662.0
# Western                                106026.0
#
#               Mid-Career 90th Percentile Salary
# Region
# California                             167909.0
# Midwestern                             147689.0
# Northeastern                           181927.0
# Southern                               152769.0
# Western                                143824.0

# %%
df_mod.groupby('Region')['Starting Median Salary'].describe().round()
# Out:
#               count     mean     std      min      25%      50%      75%  \
# Region
# California     28.0  51032.0  8982.0  38000.0  45650.0  48450.0  52825.0
# Midwestern     71.0  44225.0  5068.0  35300.0  41100.0  43100.0  46250.0
# Northeastern  100.0  48496.0  7159.0  36900.0  43150.0  47000.0  52825.0
# Southern       79.0  44522.0  5626.0  34500.0  41100.0  43400.0  47050.0
# Western        42.0  44414.0  3935.0  37300.0  42050.0  44850.0  46575.0
#
#                   max
# Region
# California    75500.0
# Midwestern    57100.0
# Northeastern  72200.0
# Southern      64000.0
# Western       58100.0

# %%
# # cast as string
# df_mod['Starting Median Salary'] = df_mod['Starting Median Salary'].astype(str)

# # format strings
# df_mod['Starting Median Salary'] = df_mod['Starting Median Salary'].str.replace(',', '')
# df_mod['Starting Median Salary'] = df_mod['Starting Median Salary'].str.replace('$', '')

# # cast back to float
# df_mod['Starting Median Salary'] = df_mod['Starting Median Salary'].astype(float).round(decimals=0)

# df_mod['Starting Median Salary'].describe().round()

# %% [markdown]
# ### Changelog
# ---
#     - originally planned to download data as csv, but figured it would be good practice to make an api call and download it that way. Haven't worked with APIs before. Keggle apparently has its own library?
#     - this still downloads locally and I doubt others would successfully be able to run this.
#     - having issues using kaggle api to download dataset
# 2/19/20
#     - first time keeping track of daily changes to notebook
#     - abondoned implimenting api for now, prioritized traversing through data and visualizing
#     - second question filepath is incorrect, which is why lists are not building correctly
# 2/20/20
#     - successfully printed the average median salary for each school type in a nice format
#     - code is clunky and not clean. working to figure out how I can clean it up. also working on visualizing means
# 2/21/20
#     - cleaned up code by removing redundant list and learning how to initialize multiple lists in one line
#     - created dictionary with school type as keys and average median salaries as the paired values
#     - used zip function with * positional argument to easily graph dictionary on bar chart
# 2/24/20
#     - formatted second bar chart
#     - cleaned up code, added comments
#     - created a git repository and uploaded this notebook to github
# 2/26/20
#     - moved directories, updated filepaths
#     - imported and read csv
# 2/27/20
#     - Ran into the same string problem as earlier. Formatted specific column (starting median salary) into float
# 2/28/20
#     - successfully used pandas to describe the starting median salary column and grouped that by region.
#     - HOWEVER, it only works because that is the only data column that is formatted into a float (i think). If all the salaries were formatted into floats, then I would be stuck with the problem of not filtering out all other columns while still grouping by region.
# 2/29/20
#     - formatted all the columns with salary data.
#     - I was correct yesterday in thinking that describe method was only displaying the correct results because it was the only column with a float type. Now figuring out how to get statistics for a single column grouped by another column. Also need to create a separate method to format strings. Would make code cleaner.
# 3/1/20
#     - Figured out solution for using describe on a single while using groupby(). Just needed to index column.
#     - Cleaned code. Added comments
#     - started to create a function to format objects into floats, but got stuck
# 3/2/20
#     - created separate function to format salary columns into float type
#     - updated github
